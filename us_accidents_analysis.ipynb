# %% [markdown]
# <a href="https://colab.research.google.com/github/viveksr755/1st_repo/blob/main/us_accidents_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **NOTE -**
# The Dataset used in this workshop was updated recently from Kaggle, here are the things changed since the live workshop.
# - The filename of the dataset has been updated, the new filename is **'./us-accidents/US_Accidents_Dec20_updated.csv'**. Please change the filename if you are getting errors while creating the dataframe.
# - The **"Source"** column is removed from the updated dataset. Any mention of "Source" in this notebook can be ignored while using the updated dataset.
#
# # US Accidents Exploratory Data Analysis
#
# TODO - talk about EDA
#
# TODO - talk about the dataset (source, what it contains, how it will be useful)
#   - Kaggle
#   - informaiton about accidents
#   - can use useful to prevent accidents
#   - mention that this does not contain data about New York

# %%
pip install opendatasets --upgrade --quiet

# %%
import opendatasets as od

download_url = 'https://www.kaggle.com/sobhanmoosavi/us-accidents'

od.download(download_url)
# Out:
# Please provide your Kaggle credentials to download this dataset. Learn more: http://bit.ly/kaggle-creds
# Your Kaggle username: viveksr56
# Your Kaggle Key: ··········
# Dataset URL: https://www.kaggle.com/datasets/sobhanmoosavi/us-accidents
# Downloading us-accidents.zip to ./us-accidents
# 100%|██████████| 653M/653M [00:04<00:00, 163MB/s]

# %%
data_filename = './us-accidents/US_Accidents_March23.csv'

# %% [markdown]
# ## Data Preparation and Cleaning
#
# 1. Load the file using Pandas
# 2. Look at some information about the data & the columns
# 3. Fix any missing or incorrect values

# %%
import pandas as pd

# %%
df = pd.read_csv(data_filename)

# %%
df
# Out:
#                 ID   Source  Severity           Start_Time  \
# 0              A-1  Source2         3  2016-02-08 05:46:00
# 1              A-2  Source2         2  2016-02-08 06:07:59
# 2              A-3  Source2         2  2016-02-08 06:49:27
# 3              A-4  Source2         3  2016-02-08 07:23:34
# 4              A-5  Source2         2  2016-02-08 07:39:07
# ...            ...      ...       ...                  ...
# 7728389  A-7777757  Source1         2  2019-08-23 18:03:25
# 7728390  A-7777758  Source1         2  2019-08-23 19:11:30
# 7728391  A-7777759  Source1         2  2019-08-23 19:00:21
# 7728392  A-7777760  Source1         2  2019-08-23 19:00:21
# 7728393  A-7777761  Source1         2  2019-08-23 18:52:06
#
#                     End_Time  Start_Lat   Start_Lng   End_Lat    End_Lng  \
# 0        2016-02-08 11:00:00  39.865147  -84.058723       NaN        NaN
# 1        2016-02-08 06:37:59  39.928059  -82.831184       NaN        NaN
# 2        2016-02-08 07:19:27  39.063148  -84.032608       NaN        NaN
# 3        2016-02-08 07:53:34  39.747753  -84.205582       NaN        NaN
# 4        2016-02-08 08:09:07  39.627781  -84.188354       NaN        NaN
# ...                      ...        ...         ...       ...        ...
# 7728389  2019-08-23 18:32:01  34.002480 -117.379360  33.99888 -117.37094
# 7728390  2019-08-23 19:38:23  32.766960 -117.148060  32.76555 -117.15363
# 7728391  2019-08-23 19:28:49  33.775450 -117.847790  33.77740 -117.85727
# 7728392  2019-08-23 19:29:42  33.992460 -118.403020  33.98311 -118.39565
# 7728393  2019-08-23 19:21:31  34.133930 -117.230920  34.13736 -117.23934
#
#          Distance(mi)  ... Roundabout Station   Stop Traffic_Calming  \
# 0               0.010  ...      False   False  False           False
# 1               0.010  ...      False   False  False           False
# 2               0.010  ...      False   False  False           False
# 3               0.010  ...      False   False  False           False
# 4               0.010  ...      False   False  False           False
# ...               ...  ...        ...     ...    ...             ...
# 7728389         0.543  ...      False   False  False           False
# 7728390         0.338  ...      False   False  False           False
# 7728391         0.561  ...      False   False  False           False
# 7728392         0.772  ...      False   False  False           False
# 7728393         0.537  ...      False   False  False           False
#
#         Traffic_Signal Turning_Loop Sunrise_Sunset Civil_Twilight  \
# 0                False        False          Night          Night
# 1                False        False          Night          Night
# 2                 True        False          Night          Night
# 3                False        False          Night            Day
# 4                 True        False            Day            Day
# ...                ...          ...            ...            ...
# 7728389          False        False            Day            Day
# 7728390          False        False            Day            Day
# 7728391          False        False            Day            Day
# 7728392          False        False            Day            Day
# 7728393          False        False            Day            Day
#
#         Nautical_Twilight Astronomical_Twilight
# 0                   Night                 Night
# 1                   Night                   Day
# 2                     Day                   Day
# 3                     Day                   Day
# 4                     Day                   Day
# ...                   ...                   ...
# 7728389               Day                   Day
# 7728390               Day                   Day
# 7728391               Day                   Day
# 7728392               Day                   Day
# 7728393               Day                   Day
#
# [7728394 rows x 46 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7728394 entries, 0 to 7728393
# Data columns (total 46 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   ID                     object
#  1   Source                 object
#  2   Severity               int64
#  3   Start_Time             object
#  4   End_Time               object
#  5   Start_Lat              float64
#  6   Start_Lng              float64
#  7   End_Lat                float64
#  8   End_Lng                float64
#  9   Distance(mi)           float64
#  10  Description            object
#  11  Street                 object
#  12  City                   object
#  13  County                 object
#  14  State                  object
#  15  Zipcode                object
#  16  Country                object
#  17  Timezone               object
#  18  Airport_Code           object
#  19  Weather_Timestamp      object
#  20  Temperature(F)         float64
#  21  Wind_Chill(F)          float64
#  22  Humidity(%)            float64
#  23  Pressure(in)           float64
#  24  Visibility(mi)         float64
#  25  Wind_Direction         object
#  26  Wind_Speed(mph)        float64
#  27  Precipitation(in)      float64
#  28  Weather_Condition      object
#  29  Amenity                bool
#  30  Bump                   bool
#  31  Crossing               bool
#  32  Give_Way               bool
#  33  Junction               bool
#  34  No_Exit                bool
#  35  Railway                bool
#  36  Roundabout             bool
#  37  Station                bool
#  38  Stop                   bool
#  39  Traffic_Calming        bool
#  40  Traffic_Signal         bool
#  41  Turning_Loop           bool
#  42  Sunrise_Sunset         object
#  43  Civil_Twilight         object
#  44  Nautical_Twilight      object
#  45  Astronomical_Twilight  object
# dtypes: bool(13), float64(12), int64(1), object(20)
# memory usage: 2.0+ GB

# %%
df.describe()
# Out:
#            Severity     Start_Lat     Start_Lng       End_Lat       End_Lng  \
# count  7.728394e+06  7.728394e+06  7.728394e+06  4.325632e+06  4.325632e+06
# mean   2.212384e+00  3.620119e+01 -9.470255e+01  3.626183e+01 -9.572557e+01
# std    4.875313e-01  5.076079e+00  1.739176e+01  5.272905e+00  1.810793e+01
# min    1.000000e+00  2.455480e+01 -1.246238e+02  2.456601e+01 -1.245457e+02
# 25%    2.000000e+00  3.339963e+01 -1.172194e+02  3.346207e+01 -1.177543e+02
# 50%    2.000000e+00  3.582397e+01 -8.776662e+01  3.618349e+01 -8.802789e+01
# 75%    2.000000e+00  4.008496e+01 -8.035368e+01  4.017892e+01 -8.024709e+01
# max    4.000000e+00  4.900220e+01 -6.711317e+01  4.907500e+01 -6.710924e+01
#
#        Distance(mi)  Temperature(F)  Wind_Chill(F)   Humidity(%)  \
# count  7.728394e+06    7.564541e+06   5.729375e+06  7.554250e+06
# mean   5.618423e-01    6.166329e+01   5.825105e+01  6.483104e+01
# std    1.776811e+00    1.901365e+01   2.238983e+01  2.282097e+01
# min    0.000000e+00   -8.900000e+01  -8.900000e+01  1.000000e+00
# 25%    0.000000e+00    4.900000e+01   4.300000e+01  4.800000e+01
# 50%    3.000000e-02    6.400000e+01   6.200000e+01  6.700000e+01
# 75%    4.640000e-01    7.600000e+01   7.500000e+01  8.400000e+01
# max    4.417500e+02    2.070000e+02   2.070000e+02  1.000000e+02
#
#        Pressure(in)  Visibility(mi)  Wind_Speed(mph)  Precipitation(in)
# count  7.587715e+06    7.551296e+06     7.157161e+06       5.524808e+06
# mean   2.953899e+01    9.090376e+00     7.685490e+00       8.407210e-03
# std    1.006190e+00    2.688316e+00     5.424983e+00       1.102246e-01
# min    0.000000e+00    0.000000e+00     0.000000e+00       0.000000e+00
# 25%    2.937000e+01    1.000000e+01     4.600000e+00       0.000000e+00
# 50%    2.986000e+01    1.000000e+01     7.000000e+00       0.000000e+00
# 75%    3.003000e+01    1.000000e+01     1.040000e+01       0.000000e+00
# max    5.863000e+01    1.400000e+02     1.087000e+03       3.647000e+01

# %%
numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']

numeric_df = df.select_dtypes(include=numerics)
len(numeric_df.columns)
# Out:
# 13

# %% [markdown]
# Percentage of missing values per column

# %%
missing_percentages = df.isna().sum().sort_values(ascending=False) / len(df)
missing_percentages
# Out:
# End_Lng                  4.402935e-01
# End_Lat                  4.402935e-01
# Precipitation(in)        2.851286e-01
# Wind_Chill(F)            2.586590e-01
# Wind_Speed(mph)          7.391355e-02
# Visibility(mi)           2.291524e-02
# Wind_Direction           2.267043e-02
# Humidity(%)              2.253301e-02
# Weather_Condition        2.244438e-02
# Temperature(F)           2.120143e-02
# Pressure(in)             1.820288e-02
# Weather_Timestamp        1.555666e-02
# Sunrise_Sunset           3.007869e-03
# Civil_Twilight           3.007869e-03
# Astronomical_Twilight    3.007869e-03
# Nautical_Twilight        3.007869e-03
# Airport_Code             2.928810e-03
# Street                   1.406372e-03
# Timezone                 1.010300e-03
# Zipcode                  2.477876e-04
# City                     3.273643e-05
# Description              6.469649e-07
# ID                       0.000000e+00
# Distance(mi)             0.000000e+00
# Start_Lng                0.000000e+00
# Source                   0.000000e+00
# Severity                 0.000000e+00
# Start_Time               0.000000e+00
# End_Time                 0.000000e+00
# Start_Lat                0.000000e+00
# County                   0.000000e+00
# Amenity                  0.000000e+00
# Country                  0.000000e+00
# State                    0.000000e+00
# Bump                     0.000000e+00
# Crossing                 0.000000e+00
# Give_Way                 0.000000e+00
# Junction                 0.000000e+00
# Station                  0.000000e+00
# Roundabout               0.000000e+00
# Railway                  0.000000e+00
# No_Exit                  0.000000e+00
# Turning_Loop             0.000000e+00
# Traffic_Signal           0.000000e+00
# Traffic_Calming          0.000000e+00
# Stop                     0.000000e+00
# dtype: float64

# %%
type(missing_percentages)
# Out:
# pandas.core.series.Series

# %%
missing_percentages[missing_percentages != 0].plot(kind='barh')
# Out:
# <Axes: >

# %% [markdown]
# Remove columns that you don't want to use.

# %% [markdown]
# ## Exploratory Analysis and Visualization
#
# Columns we'll analyze:
#
# 1. City
# 2. Start Time
# 3. Start Lat, Start Lng
# 4. Temperature
# 5. Weather Condition

# %%
df.columns
# Out:
# Index(['ID', 'Source', 'Severity', 'Start_Time', 'End_Time', 'Start_Lat',
#        'Start_Lng', 'End_Lat', 'End_Lng', 'Distance(mi)', 'Description',
#        'Street', 'City', 'County', 'State', 'Zipcode', 'Country', 'Timezone',
#        'Airport_Code', 'Weather_Timestamp', 'Temperature(F)', 'Wind_Chill(F)',
#        'Humidity(%)', 'Pressure(in)', 'Visibility(mi)', 'Wind_Direction',
#        'Wind_Speed(mph)', 'Precipitation(in)', 'Weather_Condition', 'Amenity',
#        'Bump', 'Crossing', 'Give_Way', 'Junction', 'No_Exit', 'Railway',
#        'Roundabout', 'Station', 'Stop', 'Traffic_Calming', 'Traffic_Signal',
#        'Turning_Loop', 'Sunrise_Sunset', 'Civil_Twilight', 'Nautical_Twilight',
#        'Astronomical_Twilight'],
#       dtype='object')

# %% [markdown]
# ### City

# %%
df.City
# Out:
# 0                Dayton
# 1          Reynoldsburg
# 2          Williamsburg
# 3                Dayton
# 4                Dayton
#                ...
# 7728389       Riverside
# 7728390       San Diego
# 7728391          Orange
# 7728392     Culver City
# 7728393        Highland
# Name: City, Length: 7728394, dtype: object

# %%
cities = df.City.unique()
len(cities)
# Out:
# 13679

# %%
cities_by_accident = df.City.value_counts()
cities_by_accident
# Out:
# City
# Miami            186917
# Houston          169609
# Los Angeles      156491
# Charlotte        138652
# Dallas           130939
#                   ...
# Rapid River           1
# Cat Spring            1
# Glenwood City         1
# Downing               1
# Marfa                 1
# Name: count, Length: 13678, dtype: int64

# %%
cities_by_accident[:20]
# Out:
# City
# Miami            186917
# Houston          169609
# Los Angeles      156491
# Charlotte        138652
# Dallas           130939
# Orlando          109733
# Austin            97359
# Raleigh           86079
# Nashville         72930
# Baton Rouge       71588
# Atlanta           68186
# Sacramento        66264
# San Diego         55504
# Phoenix           53974
# Minneapolis       51488
# Richmond          48845
# Oklahoma City     46092
# Jacksonville      42447
# Tucson            39304
# Columbia          38178
# Name: count, dtype: int64

# %%
type(cities_by_accident)
# Out:
# pandas.core.series.Series

# %%
cities_by_accident[:20].plot(kind='barh')
# Out:
# <Axes: ylabel='City'>

# %%
import seaborn as sns
sns.set_style("darkgrid")

# %%
sns.histplot(cities_by_accident, log_scale=True)
# Out:
# <Axes: xlabel='count', ylabel='Count'>

# %%
high_accident_cities=cities_by_accident[cities_by_accident>=1000]
low_accident_cities=cities_by_accident[cities_by_accident<1000]

# %%
len(high_accident_cities)/len(cities)
# Out:
# 0.08904159660793917

# %%
sns.distplot(high_accident_cities)
# Out:
# <ipython-input-24-50976d58a416>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(high_accident_cities)
# <Axes: xlabel='count', ylabel='Density'>

# %%
sns.distplot(low_accident_cities)
# Out:
# <ipython-input-25-a69b07a78e7c>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(low_accident_cities)
# <Axes: xlabel='count', ylabel='Density'>

# %%
cities_by_accident[cities_by_accident == 1]
# Out:
# City
# American Fork-Pleasant Grove    1
# Waldoboro                       1
# Kinsley                         1
# Killona                         1
# Jeanerette                      1
#                                ..
# Rapid River                     1
# Cat Spring                      1
# Glenwood City                   1
# Downing                         1
# Marfa                           1
# Name: count, Length: 1023, dtype: int64

# %% [markdown]
# ### Start Time

# %%
df.Start_Time
# Out:
# 0          2016-02-08 05:46:00
# 1          2016-02-08 06:07:59
# 2          2016-02-08 06:49:27
# 3          2016-02-08 07:23:34
# 4          2016-02-08 07:39:07
#                   ...
# 7728389    2019-08-23 18:03:25
# 7728390    2019-08-23 19:11:30
# 7728391    2019-08-23 19:00:21
# 7728392    2019-08-23 19:00:21
# 7728393    2019-08-23 18:52:06
# Name: Start_Time, Length: 7728394, dtype: object

# %%
df.Start_Time = pd.to_datetime(df.Start_Time, format='mixed', errors='coerce')

# %%
df.Start_Time[100]
# Out:
# Timestamp('2016-02-11 08:23:17')

# %% [markdown]
# - Figure out how to show percentages

# %%
sns.distplot(df.Start_Time.dt.hour, bins=24, kde=False, norm_hist=True)
# Out:
# <ipython-input-30-cecb2f6b7498>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.Start_Time.dt.hour, bins=24, kde=False, norm_hist=True)
# <Axes: xlabel='Start_Time'>

# %% [markdown]
# - A high percentage of accidents occur between 6 am to 10 am (probably people in a hurry to get to work)
# - Next higest percentage is 3 pm to 6 pm.

# %%
sns.distplot(df.Start_Time.dt.dayofweek, bins=7, kde=False, norm_hist=True)
# Out:
# <ipython-input-31-019c7ea578c3>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.Start_Time.dt.dayofweek, bins=7, kde=False, norm_hist=True)
# <Axes: xlabel='Start_Time'>

# %% [markdown]
# Is the distribution of accidents by hour the same on weekends as on weekdays.

# %%
sundays_start_time = df.Start_Time[df.Start_Time.dt.dayofweek == 6]
sns.distplot(sundays_start_time.dt.hour, bins=24, kde=False, norm_hist=True)
# Out:
# <ipython-input-32-6d10f1b09e8f>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(sundays_start_time.dt.hour, bins=24, kde=False, norm_hist=True)
# <Axes: xlabel='Start_Time'>

# %%
monday_start_time = df.Start_Time[df.Start_Time.dt.dayofweek == 0]
sns.distplot(monday_start_time.dt.hour, bins=24, kde=False, norm_hist=True)
# Out:
# <ipython-input-33-a0c386feb2b8>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(monday_start_time.dt.hour, bins=24, kde=False, norm_hist=True)
# <Axes: xlabel='Start_Time'>

# %% [markdown]
# On Sundays, the peak occurs between 10 am and 3 pm, unlike weekdays

# %%
df_2019 = df[df.Start_Time.dt.year == 2019]
df_2019_Bing = df_2019[df_2019.Source == 'MapQuest']
sns.distplot(df_2019_Bing.Start_Time.dt.month, bins=12, kde=False, norm_hist=True)
# Out:
# <ipython-input-34-97530c06d348>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_2019_Bing.Start_Time.dt.month, bins=12, kde=False, norm_hist=True)
# /usr/local/lib/python3.10/dist-packages/seaborn/distributions.py:2464: RuntimeWarning: Mean of empty slice.
#   line, = ax.plot(a.mean(), 0)
# /usr/local/lib/python3.10/dist-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/histograms.py:885: RuntimeWarning: invalid value encountered in divide
#   return n/db/n.sum(), bin_edges
# <Axes: xlabel='Start_Time'>

# %% [markdown]
# Can you explain the month-wise trend of accidents?
#
# - Much data is missing for 2016. Maybe even 2017.
# - There seems to be some issue with the Bing data

# %%
df.Source.value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# - Consider excluding Bing data, seems to have issues.

# %% [markdown]
# ### Start Latitude & Longitude

# %%
df.Start_Lat
# Out:
# 0          39.865147
# 1          39.928059
# 2          39.063148
# 3          39.747753
# 4          39.627781
#              ...
# 7728389    34.002480
# 7728390    32.766960
# 7728391    33.775450
# 7728392    33.992460
# 7728393    34.133930
# Name: Start_Lat, Length: 7728394, dtype: float64

# %%
df.Start_Lng
# Out:
# 0          -84.058723
# 1          -82.831184
# 2          -84.032608
# 3          -84.205582
# 4          -84.188354
#               ...
# 7728389   -117.379360
# 7728390   -117.148060
# 7728391   -117.847790
# 7728392   -118.403020
# 7728393   -117.230920
# Name: Start_Lng, Length: 7728394, dtype: float64

# %%
sample_df = df.sample(int(0.1 * len(df)))

# %%
sns.scatterplot(x=sample_df.Start_Lng, y=sample_df.Start_Lat, size=0.001)
# Out:
# <Axes: xlabel='Start_Lng', ylabel='Start_Lat'>

# %%
#!pip install folium
import folium
# Out:
# Collecting folium
#   Downloading folium-0.18.0-py2.py3-none-any.whl.metadata (3.8 kB)
# Collecting branca>=0.6.0 (from folium)
#   Downloading branca-0.8.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: jinja2>=2.9 in /usr/local/lib/python3.10/dist-packages (from folium) (3.1.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from folium) (1.26.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from folium) (2.32.3)
# Collecting xyzservices (from folium)
#   Downloading xyzservices-2024.9.0-py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2>=2.9->folium) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->folium) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->folium) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->folium) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->folium) (2024.8.30)
# Downloading folium-0.18.0-py2.py3-none-any.whl (108 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 108.9/108.9 kB 2.3 MB/s eta 0:00:00
# Downloading branca-0.8.0-py3-none-any.whl (25 kB)
# Downloading xyzservices-2024.9.0-py3-none-any.whl (85 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.1/85.1 kB 4.0 MB/s eta 0:00:00
# Installing collected packages: xyzservices, branca, folium
# Successfully installed branca-0.8.0 folium-0.18.0 xyzservices-2024.9.0

# %%
lat, lon = df.Start_Lat[0], df.Start_Lng[0]
lat, lon
# Out:
# (39.865147, -84.058723)

# %%
for x in df[['Start_Lat', 'Start_Lng']].sample(100).iterrows():
    print(x[1])
# Out:
# Start_Lat    40.073533
# Start_Lng   -75.152279
# Name: 4178102, dtype: float64
# Start_Lat    28.449924
# Start_Lng   -81.479136
# Name: 4158133, dtype: float64
# Start_Lat    28.217043
# Start_Lng   -82.718895
# Name: 131027, dtype: float64
# Start_Lat    25.627259
# Start_Lng   -80.384389
# Name: 4208053, dtype: float64
# Start_Lat    29.947308
# Start_Lng   -95.397079
# Name: 3137823, dtype: float64
# Start_Lat    33.89865
# Start_Lng   -84.47028
# Name: 7521976, dtype: float64
# Start_Lat    29.733576
# Start_Lng   -95.368210
# Name: 453283, dtype: float64
# Start_Lat     37.578770
# Start_Lng   -122.048424
# Name: 1019053, dtype: float64
# Start_Lat     32.235912
# Start_Lng   -110.968706
# Name: 4805582, dtype: float64
# Start_Lat    43.011542
# Start_Lng   -74.852468
# Name: 4855502, dtype: float64
# Start_Lat    41.525263
# Start_Lng   -73.878840
# Name: 4651644, dtype: float64
# Start_Lat    37.357388
# Start_Lng   -76.736358
# Name: 6568736, dtype: float64
# Start_Lat    37.180688
# Start_Lng   -93.237758
# Name: 4198591, dtype: float64
# Start_Lat    26.637150
# Start_Lng   -80.121239
# Name: 1662731, dtype: float64
# Start_Lat    34.869122
# Start_Lng   -82.416725
# Name: 3103153, dtype: float64
# Start_Lat    39.035314
# Start_Lng   -94.500114
# Name: 6131315, dtype: float64
# Start_Lat    32.004604
# Start_Lng   -81.283600
# Name: 2449459, dtype: float64
# Start_Lat     34.078466
# Start_Lng   -118.228587
# Name: 7319397, dtype: float64
# Start_Lat     37.701893
# Start_Lng   -121.898567
# Name: 5227447, dtype: float64
# Start_Lat    39.823799
# Start_Lng   -86.256187
# Name: 1877926, dtype: float64
# Start_Lat     37.914585
# Start_Lng   -122.317520
# Name: 3067584, dtype: float64
# Start_Lat    30.229870
# Start_Lng   -92.012131
# Name: 1318442, dtype: float64
# Start_Lat    41.138653
# Start_Lng   -95.946373
# Name: 470627, dtype: float64
# Start_Lat    44.954803
# Start_Lng   -93.400719
# Name: 1741058, dtype: float64
# Start_Lat    36.073425
# Start_Lng   -95.922096
# Name: 534674, dtype: float64
# Start_Lat    41.143665
# Start_Lng   -74.745388
# Name: 5242249, dtype: float64
# Start_Lat     33.974758
# Start_Lng   -118.256462
# Name: 819875, dtype: float64
# Start_Lat    25.894679
# Start_Lng   -80.124393
# Name: 6193580, dtype: float64
# Start_Lat    30.249936
# Start_Lng   -81.541565
# Name: 3721441, dtype: float64
# Start_Lat     34.092571
# Start_Lng   -117.898979
# Name: 403920, dtype: float64
# Start_Lat    35.390342
# Start_Lng   -84.722646
# Name: 3778005, dtype: float64
# Start_Lat     34.420231
# Start_Lng   -117.385576
# Name: 6724751, dtype: float64
# Start_Lat     45.729111
# Start_Lng   -122.875860
# Name: 7380642, dtype: float64
# Start_Lat    29.438339
# Start_Lng   -98.460945
# Name: 303747, dtype: float64
# Start_Lat    38.296001
# Start_Lng   -77.505203
# Name: 1873000, dtype: float64
# Start_Lat    33.743698
# Start_Lng   -84.378059
# Name: 682885, dtype: float64
# Start_Lat    30.046190
# Start_Lng   -95.183937
# Name: 1467819, dtype: float64
# Start_Lat     36.958698
# Start_Lng   -121.967937
# Name: 7215543, dtype: float64
# Start_Lat     36.764211
# Start_Lng   -119.749460
# Name: 7294054, dtype: float64
# Start_Lat    40.685509
# Start_Lng   -73.726318
# Name: 926465, dtype: float64
# Start_Lat    39.284105
# Start_Lng   -76.540675
# Name: 3777838, dtype: float64
# Start_Lat     37.780933
# Start_Lng   -122.173271
# Name: 7715, dtype: float64
# Start_Lat    40.891918
# Start_Lng   -76.914543
# Name: 4064369, dtype: float64
# Start_Lat    32.691292
# Start_Lng   -96.823250
# Name: 394146, dtype: float64
# Start_Lat     34.032161
# Start_Lng   -117.671590
# Name: 5618357, dtype: float64
# Start_Lat     40.352810
# Start_Lng   -111.275525
# Name: 5322446, dtype: float64
# Start_Lat    41.493247
# Start_Lng   -94.662419
# Name: 6757822, dtype: float64
# Start_Lat    32.740155
# Start_Lng   -96.822845
# Name: 4658256, dtype: float64
# Start_Lat    29.162243
# Start_Lng   -81.857651
# Name: 4436663, dtype: float64
# Start_Lat    34.712762
# Start_Lng   -81.217293
# Name: 3914329, dtype: float64
# Start_Lat     34.138330
# Start_Lng   -117.242349
# Name: 6400832, dtype: float64
# Start_Lat    31.187695
# Start_Lng   -89.252128
# Name: 5649730, dtype: float64
# Start_Lat    33.765110
# Start_Lng   -84.494072
# Name: 532981, dtype: float64
# Start_Lat     34.086183
# Start_Lng   -117.776844
# Name: 4721364, dtype: float64
# Start_Lat    38.959042
# Start_Lng   -77.499268
# Name: 1732634, dtype: float64
# Start_Lat     40.718269
# Start_Lng   -111.985596
# Name: 1002410, dtype: float64
# Start_Lat     35.528290
# Start_Lng   -119.565374
# Name: 3818808, dtype: float64
# Start_Lat    42.34814
# Start_Lng   -83.10587
# Name: 3469932, dtype: float64
# Start_Lat    28.598106
# Start_Lng   -81.717194
# Name: 1035209, dtype: float64
# Start_Lat     34.035561
# Start_Lng   -118.169907
# Name: 2254239, dtype: float64
# Start_Lat    41.463502
# Start_Lng   -81.657356
# Name: 4720104, dtype: float64
# Start_Lat    25.761009
# Start_Lng   -80.481293
# Name: 3353664, dtype: float64
# Start_Lat     33.990490
# Start_Lng   -117.924316
# Name: 654586, dtype: float64
# Start_Lat    45.815153
# Start_Lng   -94.280285
# Name: 6546783, dtype: float64
# Start_Lat    29.686766
# Start_Lng   -95.508781
# Name: 1301218, dtype: float64
# Start_Lat    40.415765
# Start_Lng   -77.931073
# Name: 5869393, dtype: float64
# Start_Lat    37.513817
# Start_Lng   -77.407616
# Name: 825107, dtype: float64
# Start_Lat     37.850973
# Start_Lng   -122.299481
# Name: 4369724, dtype: float64
# Start_Lat    38.958538
# Start_Lng   -77.028223
# Name: 6115542, dtype: float64
# Start_Lat    36.943592
# Start_Lng   -77.392029
# Name: 746347, dtype: float64
# Start_Lat     41.06222
# Start_Lng   -111.54470
# Name: 7234197, dtype: float64
# Start_Lat    40.536136
# Start_Lng   -75.735319
# Name: 6258080, dtype: float64
# Start_Lat    39.333879
# Start_Lng   -80.076576
# Name: 5756683, dtype: float64
# Start_Lat    25.915448
# Start_Lng   -80.210143
# Name: 3436611, dtype: float64
# Start_Lat    25.760880
# Start_Lng   -80.418865
# Name: 4237545, dtype: float64
# Start_Lat    32.755863
# Start_Lng   -83.709641
# Name: 1629756, dtype: float64
# Start_Lat    33.767259
# Start_Lng   -84.388999
# Name: 3850978, dtype: float64
# Start_Lat    34.851711
# Start_Lng   -82.402191
# Name: 720761, dtype: float64
# Start_Lat    28.481577
# Start_Lng   -81.458700
# Name: 6257548, dtype: float64
# Start_Lat     32.658226
# Start_Lng   -117.074547
# Name: 2761577, dtype: float64
# Start_Lat     37.88780
# Start_Lng   -122.30926
# Name: 7015781, dtype: float64
# Start_Lat    27.322148
# Start_Lng   -81.411517
# Name: 6202703, dtype: float64
# Start_Lat    38.904319
# Start_Lng   -77.017602
# Name: 6037566, dtype: float64
# Start_Lat    37.052452
# Start_Lng   -76.407722
# Name: 687806, dtype: float64
# Start_Lat    25.668404
# Start_Lng   -80.416195
# Name: 5838692, dtype: float64
# Start_Lat    39.88096
# Start_Lng   -75.54673
# Name: 7668733, dtype: float64
# Start_Lat    28.541624
# Start_Lng   -81.447517
# Name: 2469467, dtype: float64
# Start_Lat     45.717249
# Start_Lng   -108.699379
# Name: 6187554, dtype: float64
# Start_Lat     45.469292
# Start_Lng   -122.857918
# Name: 865683, dtype: float64
# Start_Lat    39.750278
# Start_Lng   -75.566071
# Name: 1420930, dtype: float64
# Start_Lat    39.898560
# Start_Lng   -76.159302
# Name: 2988296, dtype: float64
# Start_Lat    32.475904
# Start_Lng   -83.742866
# Name: 4768231, dtype: float64
# Start_Lat     36.751972
# Start_Lng   -119.775864
# Name: 1521386, dtype: float64
# Start_Lat     44.842529
# Start_Lng   -123.008492
# Name: 2086171, dtype: float64
# Start_Lat    28.520380
# Start_Lng   -81.359917
# Name: 1711310, dtype: float64
# Start_Lat    40.116202
# Start_Lng   -75.278138
# Name: 5151597, dtype: float64
# Start_Lat    40.232758
# Start_Lng   -79.583100
# Name: 4312645, dtype: float64
# Start_Lat    29.93893
# Start_Lng   -95.37492
# Name: 7617986, dtype: float64
# Start_Lat    32.689859
# Start_Lng   -96.835190
# Name: 4168937, dtype: float64
# Start_Lat    38.453994
# Start_Lng   -77.407631
# Name: 3898013, dtype: float64

# %%
zip(list(df.Start_Lat), list(df.Start_Lng))

# %%
from folium.plugins import HeatMap

# %%
sample_df = df.sample(int(0.001 * len(df)))
lat_lon_pairs = list(zip(list(sample_df.Start_Lat), list(sample_df.Start_Lng)))

# %%
map = folium.Map()
HeatMap(lat_lon_pairs).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1af290b1831df2c99cb605a27c4e4d6f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1af290b1831df2c99cb605a27c4e4d6f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1af290b1831df2c99cb605a27c4e4d6f = L.map(
#                 &quot;map_1af290b1831df2c99cb605a27c4e4d6f&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_cc83df2fb4e02cef95e44e7abd4c81e5 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_cc83df2fb4e02cef95e44e7abd4c81e5.addTo(map_1af290b1831df2c99cb605a27c4e4d6f);
#
#
#             var heat_map_0ca7d0a7f837ad468e6d1cdfa57b5f48 = L.heatLayer(
#                 [[47.666378, -122.299553], [36.138039, -86.805038], [41.90238118, -88.10023427], [42.003017, -88.026436], [25.884164, -80.201112], [45.533129, -122.623345], [33.938202000000004, -118.348259], [33.960152, -118.254028], [42.237025, -83.734098], [33.95328, -117.305875], [45.205494, -122.828553], [30.152124, -81.750128], [44.489311, -87.939423], [33.548431, -81.662994], [38.02253365498532, -78.54481100998619], [29.388694, -82.205913], [40.56004, -77.27591899999999], [39.174759, -94.560806], [38.966933, -121.02011], [28.552392, -81.448734], [32.225109, -111.020279], [33.911325, -118.164524], [46.37986779190836, -112.02952980941755], [33.856148, -117.998711], [39.76178400000001, -105.439164], [40.216473, -76.090576], [30.1737, -97.823792], [40.779917, -73.605398], [33.671162, -117.828217], [40.77117, -112.030645], [45.505845, -122.754443], [34.026843, -118.429919], [29.956231, -90.091664], [38.418331, -121.224838], [41.584872, -72.053242], [32.720245, -86.53218100000002], [34.854315, -82.227485], [37.88178, -122.30826], [42.21765900000001, -78.324318], [34.06933, -118.235847], [37.24827, -121.83147], [34.72308, -86.627571], [44.308328, -121.1724], [35.478901, -97.724701], [44.208984, -117.147403], [33.874149, -117.88053899999998], [42.199932, -87.86495500000002], [40.52691, -74.329312], [33.824777000000005, -84.42373], [47.423934, -122.2827], [38.194611, -77.18], [37.808498, -122.366852], [37.472156, -119.95295], [34.143162, -80.750168], [37.248249, -80.20476500000002], [33.872688000000004, -118.290894], [40.271613, -75.286498], [37.701477, -122.021132], [32.382645000000004, -111.04693600000002], [32.661369, -97.252609], [33.883948, -117.525285], [41.87673, -72.267376], [34.062363, -81.045967], [47.568989, -122.313354], [37.623937, -77.554448], [30.232197, -97.799271], [40.728344, -73.92813199999998], [33.817569, -117.425569], [41.22377, -96.03388], [44.956405, -93.269653], [29.866585, -95.487273], [44.970044, -93.314838], [34.05256, -118.25752], [47.43551, -111.50145], [39.306998, -120.539992], [37.295361, -120.324852], [40.020664, -76.741837], [32.949551, -96.735428], [35.336011, -80.828514], [33.547815084297426, -86.7494094367659], [30.471308, -91.10063], [35.256296, -82.409275], [32.678699, -96.764809], [39.158801, -94.497752], [29.718605, -95.504168], [37.77755300000001, -79.400971], [40.0159, -82.901855], [32.968494, -80.148699], [33.715496, -117.844664], [30.25774, -81.435799], [36.922999, -76.280511], [36.706662, -119.773984], [39.01345, -77.03894], [38.591346, -121.504694], [45.31260200000001, -93.827658], [26.508006, -80.07431], [34.04243, -81.086702], [34.741304, -92.282749], [39.72556, -105.02991000000002], [36.140649, -95.90893], [39.404042, -77.39272700000002], [36.143452, -86.793785], [42.228107, -83.385948], [37.966634, -122.048958], [30.24408, -92.008614], [32.793732, -96.747368], [37.77455, -122.2318], [34.025207, -118.433563], [35.377262, -97.574974], [33.120045000000005, -80.27552800000002], [28.780038, -81.3535], [36.75484, -119.765357], [33.757339, -78.966812], [40.496021, -79.656601], [38.23128300000001, -122.111905], [35.012456, -85.325097], [36.797428, -119.785439], [46.878359, -113.90886], [42.258099, -88.140198], [34.121976000000004, -118.340241], [39.257169, -121.197788], [34.268987, -84.807459], [35.399612, -82.508415], [33.50369, -81.847319], [35.228138, -80.84414699999998], [41.981049, -73.715683], [34.066727, -117.218842], [26.470514, -81.812887], [35.80035, -78.56276700000002], [39.08372, -77.07794], [27.95628, -82.49739], [34.8004, -82.37647199999998], [43.08276, -75.326202], [40.725562, -112.219541], [33.666203, -81.674118], [37.825519, -122.304736], [32.826640999999995, -97.385025], [33.867107, -117.744831], [32.507542, -110.886031], [33.46192, -112.09413], [34.915128, -82.854075], [35.339474, -119.003006], [33.928724, -118.102845], [40.69944, -73.98855], [34.117709000000005, -117.851821], [40.731972, -73.871063], [38.9

# %% [markdown]
# ## Ask & answer questions
#
# 1. Are there more accidents in warmer or colder areas?
# 2. Which 5 states have the highest number of accidents? How about per capita?
# 3. Does New York show up in the data? If yes, why is the count lower if this the most populated city.
# 4. Among the top 100 cities in number of accidents, which states do they belong to most frequently.
# 5. What time of the day are accidents most frequent in? - ANSWERED
# 6. Which days of the week have the most accidents?
# 7. Which months have the most accidents?
# 8. What is the trend of accidents year over year (decreasing/increasing?)
# 9. When is accidents per unit of traffic the highest.

# %% [markdown]
# ## Summary and Conclusion
#
#
# Insights:
# - No data from New York
# - The number of accidents per city decreases exponentially
# - Less than 10% of cities have more than 1000 yearly accidents.
# - Over 1200 cities have reported just one accident (need to investigate)

# %%
#!pip install jovian
import jovian
# Out:
# Collecting jovian
#   Downloading jovian-0.2.47-py2.py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from jovian) (2.32.3)
# Collecting uuid (from jovian)
#   Downloading uuid-1.30.tar.gz (5.8 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from jovian) (6.0.2)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from jovian) (8.1.7)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->jovian) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->jovian) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->jovian) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->jovian) (2024.8.30)
# Downloading jovian-0.2.47-py2.py3-none-any.whl (68 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.6/68.6 kB 1.9 MB/s eta 0:00:00
# Building wheels for collected packages: uuid
#   Building wheel for uuid (setup.py) ... done
#   Created wheel for uuid: filename=uuid-1.30-py3-none-any.whl size=6478 sha256=62c940a2a967346f47bd1a4370137f817dd323443a9a1663e9f4e2acc1a08a1c
#   Stored in directory: /root/.cache/pip/wheels/ed/08/9e/f0a977dfe55051a07e21af89200125d65f1efa60cbac61ed88
# Successfully built uuid
# Installing collected packages: uuid, jovian
# Successfully installed jovian-0.2.47 uuid-1.30

# %%
jovian.commit()
# Out:
# [jovian] Detected Colab notebook...
# [jovian] jovian.commit() is no longer required on Google Colab. If you ran this notebook from Jovian,
# then just save this file in Colab using Ctrl+S/Cmd+S and it will be updated on Jovian.
# Also, you can also delete this cell, it's no longer necessary.
